# %%
import pandas as pd
import sqlite3

filename='GSL_Ops.xlsx'   
conn = sqlite3.connect('customer.db')
cur=conn.cursor()
df = pd.read_sql_query("Select CR.customer_id,CR.revenue, CST.region, CST.country, CST.team \
            From CustomerRevenue as CR \
            Left Join CustomerSalesTeam as CST \
            on CR.customer_id = CST.customer_id; ", conn)
df
# Out:
#      customer_id      revenue    region country            team
# 0            104   142.838690      None    None            None
# 1            327   417.888666      None    None            None
# 2            430  1290.284869      None    None            None
# 3            538   267.070334      None    None            None
# 4            585   349.063643      None    None            None
# 5            775   501.019332      None    None            None
# 6            823   108.366170      None    None            None
# 7            961   256.015551      None    None            None
# 8            997   253.603649      None    None            None
# 9           1102   764.635582      None    None            None
# 10          1115  5773.934426      None    None            None
# 11          1255  9793.099887      None    None            None
# 12          1393  2445.488002      None    None            None
# 13          1557   734.456390      None    None            None
# ...
